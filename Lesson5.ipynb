# %%
import requests

# %%
url="https://raw.githubusercontent.com/BMarlinVCU/INFO450F26a/refs/heads/main/Lesson5/soccer.json"
response=requests.get(url)
response.status_code
response.raise_for_status()
data=response.json()
data.keys()
data['matches'][103]
